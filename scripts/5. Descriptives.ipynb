# %% [markdown]
# # count by topic

# %%
import matplotlib.pyplot as plt
labels = 'Covid-19', 'Election-left', 'Election-right', 'Gun violence', 'Gender', 'Immigration', 'Drug', 'Tax', 'Social security'
sizes = [23209, 100000, 100000, 70394, 29162, 70717, 100000, 100000, 39075]

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sentiment = SentimentIntensityAnalyzer()
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\PAHADRIANUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import seaborn as sns
colors = sns.color_palette('pastel')[0:5]

# %%
plt.pie(sizes, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# # Check correlation between popularity and followers count

# %%
df = pd.read_csv('data.csv')
df = senti_var(df)

# %%
df['pop'] = df['likes'] + df['retweet']

# %%
check = df[df['pop']!=0]

# %%
stats.pearsonr(biden['pop'], biden['followers'])
# Out:
# (0.2673205415501503, 0.0)

# %%
sns.scatterplot(data=check, x="followers", y="pop")
